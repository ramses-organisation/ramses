# %% [markdown]
# ### Model S Simulations
#
# __José Roberto Canivete Cuissa__
# __19.01.2023, Zurich__
#
# ---------
#
# This Notebook analyses 3D test simulations with the Model S profile

# %% [markdown]
# ----------
#
# ## Imports and constants

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import astropy.constants as const
import astropy.units as u
from ramses_global_models import RamsesOutput
from mpl_toolkits.axes_grid1 import make_axes_locatable


# Files
folder_data = '/home/jcaniv/scratch/eiger/dynamo/'
level = 8
# Constants
norm_d = 1.0
norm_v = 10.0**8
norm_p = 10.0**16
norm_B = np.sqrt(norm_d)*norm_v
norms = {'density':norm_d, 
         'pressure':norm_p, 
         'velocity':norm_v, 
         'B_field':norm_B}

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# -----------
#
# ## Read data and plot some quantities

# %%
# Output choice
n = 51

output = RamsesOutput()
output.read(folder_data, n, norms=norms)
# Out:
# Processing 576 files in /home/jcaniv/scratch/eiger/dynamo/output_00051
#  10% : read     211176 cells,          0 particles
#  20% : read     422344 cells,          0 particles
#  30% : read     629872 cells,          0 particles
#  40% : read     841040 cells,          0 particles
#  50% : read    1048576 cells,          0 particles
#  60% : read    1259744 cells,          0 particles
#  70% : read    1470920 cells,          0 particles
#  80% : read    1678456 cells,          0 particles
#  90% : read    1889624 cells,          0 particles
# Loaded: 2097152 cells, 0 particles.

# %% [markdown]
# ## Plot Perturbations

# %% [markdown]
# #### plotting routine

# %%
def plot_2D_perturbations(output):
    """ Simple routine to make 2D plots of different quantities """
    # Constants
    rsun = 695.7 # Mm
    boxsize = output.dx*(2**output.levelmax)
    # Initialize figure
    fig, axes = plt.subplots(3,2, figsize=(8,12))
    # Central slice index
    central_idx = int((2**output.levelmax)/2)
    # Compute perturbations
    d_prime = (np.abs(output.d - output.deq)/output.deq)[central_idx]
    p_prime = (np.abs(output.p - output.peq)/output.peq)[central_idx]
    s_prime = (np.abs(output.s - output.seq)/output.seq)[central_idx]
    e_prime = (np.abs(output.etot - output.etoteq)/output.etoteq)[central_idx]
    v_prime = (np.abs(output.v.norm/np.sqrt(1.6667*output.peq/output.deq)))[central_idx]
    B_prime = np.abs(output.B.norm)[central_idx]
    primes = [d_prime, p_prime, s_prime, e_prime, v_prime, B_prime]
    labels = ['density', 'pressure', 'entropy', 'energy', 'Mach number', 'B field']
    for ax,q,title in zip(axes.ravel(), primes, labels):
        # Compute vmax and vim
        #vmax = np.max(np.log10(q))
        #vmin = np.min(np.log10(q))

        # Make imshow
        cs = ax.imshow(np.log10(q).T, 
                       origin='lower',
                       #vmax=vmax,
                       #vmin=vmin,
                       extent=[-boxsize/2,boxsize/2,-boxsize/2,boxsize/2],
                       cmap='nipy_spectral')
        # Plot circles of different regions
        boundaries = [4.86990e2, 6.60915e2]
        for b in boundaries:
            interface = plt.Circle((0, 0), b, color='k', fill=None)
            ax.add_patch(interface)

        # Colorbar
        divider = make_axes_locatable(ax)
        cax = divider.new_vertical(size = '3%', pad = 0.03)
        fig.add_axes(cax)
        fig.colorbar(cs, cax = cax, orientation = 'horizontal', label=title)
        cax.xaxis.set_ticks_position('top')
        cax.xaxis.set_label_position('top')
    
    return axes, fig

# %%
plot_2D_perturbations(output)
# Out:
# (array([[<AxesSubplot: >, <AxesSubplot: >],
#         [<AxesSubplot: >, <AxesSubplot: >],
#         [<AxesSubplot: >, <AxesSubplot: >]], dtype=object),
#  <Figure size 800x1200 with 12 Axes>)

# %%
# %matplotlib inline
def plot_2D_perturbations_reduced(output):
    """ Simple routine to make 2D plots of different quantities """
    # Constants
    rsun = 695.7 # Mm
    boxsize = output.dx*(2**output.levelmax)
    # Initialize figure
    fig, axes = plt.subplots(3,1, figsize=(5,14))
    # Central slice index
    central_idx = int((2**output.levelmax)/2)
    # Compute perturbations
    s_prime = (np.abs(output.s - output.seq)/output.seq)[central_idx]
    v_prime = np.abs(output.v.norm)[central_idx]
    B_prime = np.abs(output.B.norm)[central_idx]
    primes = [s_prime, v_prime, B_prime]
    labels = [r'$log_{10}(s^{\prime})$', r'$log_{10}(|v|)$', r'$log_{10}(|B|)$']
    for ax,q,title in zip(axes.ravel(), primes, labels):
        # Compute vmax and vim
        if title==r'$log_{10}(|B|)$':
            vmax = 5
            vmin = -2
        else:
            vmax = np.max(np.log10(q))
            vmin = np.min(np.log10(q))

        # Make imshow
        cs = ax.imshow(np.log10(q).T, 
                       origin='lower',
                       vmax=vmax,
                       vmin=vmin,
                       extent=[-boxsize/2,boxsize/2,-boxsize/2,boxsize/2],
                       cmap='nipy_spectral')
        # Plot circles of different regions
        boundaries = [4.86990e2, 6.60915e2]
        for b in boundaries:
            interface = plt.Circle((0, 0), b, color='k', fill=None)
            ax.add_patch(interface)

        # Colorbar
        divider = make_axes_locatable(ax)
        cax = divider.new_vertical(size = '3%', pad = 0.03)
        fig.add_axes(cax)
        fig.colorbar(cs, cax = cax, orientation = 'horizontal', label=title)
        cax.xaxis.set_ticks_position('top')
        cax.xaxis.set_label_position('top')
    
    return axes, fig

# %%
axes, fig = plot_2D_perturbations_reduced(output)
fig.tight_layout()
#fig.savefig('modelS_dynamo.png', dpi=200)

# %% [markdown]
# ### Plot average profiles

# %% [markdown]
# #### Plotting routine

# %%
def plot_2D_radial_profiles(output):
    """ 
    Averages radially the quantities of the output and compares them to
    the equilibrium profiles
    """
    # Constants
    rsun = 695.7 # Mm
    boxsize = output.dx*(2**output.levelmax)
    # Initialize figure
    fig, axes = plt.subplots(3,2, figsize=(8,12))
    # Get number of cells per dimension
    N = 2**output.levelmax
    dx = output.dx
    # Boundaries
    boundaries = [4.86990e2, 6.60915e2]
    # Build radial coordinate
    x,y,z = np.meshgrid(np.arange(N), np.arange(N), np.arange(N))
    x = x-(N-1)/2
    y = y-(N-1)/2
    z = z-(N-1)/2
    r = np.sqrt(x**2 + y**2 + z**2)
    r = np.array(r, dtype=int)
    r_Mm = np.arange(np.max(r)+1)/(np.max(r)+1)*boxsize/2*np.sqrt(3)
    # Get quantities to plot
    quantities = [output.d, output.p, output.s, output.etot, output.v.norm, output.B.norm]
    equilibriums = [output.deq, output.peq, output.seq, output.etoteq, np.zeros(output.v.norm.shape), np.zeros(output.B.norm.shape)]
    labels = ['density', 'pressure', 'entropy', 'energy', 'velocity', 'B field'] 
    mean_quantities = []
    for ax, q, eq, title in zip(axes.ravel(), quantities, equilibriums, labels):
        q_mean = []
        qeq_mean = []
        for i in np.arange(np.max(r)+1):
            q_mean.append(np.mean(q[r==i]))
            qeq_mean.append(np.mean(eq[r==i]))
        q_mean = np.array(q_mean)
        qeq_mean = np.array(qeq_mean)
        ax.plot(r_Mm, q_mean, color='blue')
        ax.plot(r_Mm, qeq_mean, color='black')
        for b in boundaries:
            ax.axvline(b, linestyle=':', color='gray')
        ax.set_title(title)
        ax.set_yscale('log')
        if title=='B field':
            ax.set_ylim([1e-5, 1e3])
        mean_quantities.append(q_mean)
    return mean_quantities, fig

# %%
mean_profiles, fig = plot_2D_radial_profiles(output)
fig.tight_layout()
#fig.savefig('modelS_profiles.png', dpi=200)

# %% [markdown]
# -----------------
# ## Plot perturbation around average value

# %%
def compute_radial_average_grid2(q_mean_profile, r):
    r_range = np.arange(np.max(r))
    print(r.shape, r_range.shape, q_mean_profile.shape) 
    q_mean_grid = np.interp(r, r_range, q_mean_profile)
    return q_mean_grid


def compute_radial_average_grid(q, r):
    """ Computes a grid with the average radial value of a quantity at the given radius in each pixel """
    q_mean = np.zeros(r.shape)
    for r_target in np.arange(np.max(r)+1):
        # Compute the average
        mask = np.where(r==r_target)
        q_mean_radius = np.mean(q[mask])
        q_mean[mask] = q_mean_radius
    mask = np.where(r==0)
    q_mean[mask] = q[mask]
    return q_mean

def compute_radial_coordinate(levelmax):
    # Get number of cells per dimension
    N = 2**levelmax
    # Build radial coordinate
    x,y,z = np.meshgrid(np.arange(N), np.arange(N), np.arange(N))
    x = x-(N-1)/2
    y = y-(N-1)/2
    z = z-(N-1)/2
    r = np.sqrt(x**2 + y**2 + z**2)
    r = np.array(r)#, dtype=int)
    return r

def plot_2D_perturbations_around_average(output, mean_profiles):
    """ Simple routine to make 2D plots of different quantities """
    # Constants
    rsun = 695.7 # Mm
    boxsize = output.dx*(2**output.levelmax)
    # Central slice index
    central_idx = int((2**output.levelmax)/2)
    # Compute radial coordinates
    r = compute_radial_coordinate(output.levelmax)
    # Initialize figure
    fig, axes = plt.subplots(3,2, figsize=(8,12))
    # Compute perturbations
    quantities = [output.d, output.p, output.s, output.etot, output.v.norm, output.B.norm]
    labels = ['density', 'pressure', 'entropy', 'energy', 'velocity', 'B field']
    for ax,q,profile,title in zip(axes.ravel(), quantities, mean_profiles, labels):
        # Compute average grid
        q_mean = compute_radial_average_grid2(profile, r)
        q_prime = ((q - q_mean))[:,central_idx]
        # Compute vmax and vim
        # vmax = np.max(q_prime)
        # vmin = np.min(q_prime)

        # Make imshow
        cs = ax.imshow(q_prime.T, 
                       origin='lower',
                       # vmax=vmax,
                       # vmin=vmin,
                       extent=[-boxsize/2,boxsize/2,-boxsize/2,boxsize/2],
                       cmap='nipy_spectral')
        # Plot circles of different regions
        boundaries = [4.86990e2, 6.60915e2]
        for b in boundaries:
            interface = plt.Circle((0, 0), b, color='k', fill=None)
            ax.add_patch(interface)

        # Colorbar
        divider = make_axes_locatable(ax)
        cax = divider.new_vertical(size = '3%', pad = 0.03)
        fig.add_axes(cax)
        fig.colorbar(cs, cax = cax, orientation = 'horizontal', label=title)
        cax.xaxis.set_ticks_position('top')
        cax.xaxis.set_label_position('top')
    
    return axes, fig

# %%
plot_2D_perturbations_around_average(output, mean_profiles)
# Out:
# (128, 128, 128) (110,) (110,)
# (128, 128, 128) (110,) (110,)
# (128, 128, 128) (110,) (110,)
# (128, 128, 128) (110,) (110,)
# (128, 128, 128) (110,) (110,)
# (128, 128, 128) (110,) (110,)
# (array([[<AxesSubplot: >, <AxesSubplot: >],
#         [<AxesSubplot: >, <AxesSubplot: >],
#         [<AxesSubplot: >, <AxesSubplot: >]], dtype=object),
#  <Figure size 800x1200 with 12 Axes>)

# %% [markdown]
# -----------------------
#
# ## Energy analysis

# %%
def internal_energy(output):
    """ Compute the internal energy density of an output """
    gamma = 5./3.
    ei = output.p/(gamma - 1.0)
    return ei

def kinetic_energy(output):
    """ Compute the kinetic energy density of an output """
    ekin = 0.5*output.d*(output.v.x**2 + output.v.y**2)
    return ekin

def magnetic_energy(output):
    """ Compute the magnetic energy density of an output """
    emag = 0.5*(output.B.x**2 + output.B.y**2)
    return emag

def total_energy(output):
    """ Computes the total energy density of an output and its components """
    ei = internal_energy(output)
    ekin = kinetic_energy(output)
    emag = magnetic_energy(output)
    etot = ei+ekin+emag
    energy = {'etot':etot, 'ei':ei, 'ekin':ekin, 'emag':emag}
    return energy

def compute_energy_evolution(n_outputs):
    """ Given a set of output numbers, it computes the average energy components of the outputs """
    energy_evolution = []
    # Loop
    for n in n_outputs:
        output = RamsesOutput()
        output.read(folder_data, n, norms=norms)
        energy_output = total_energy(output) 
        mean_values = np.array([np.mean(energy_output[k]) for k in energy_output.keys()])
        energy_evolution.append(mean_values)
    energy_evolution = np.array(energy_evolution)
    return energy_evolution


def compute_conv_zone_energy_evolution(n_outputs, levelmax):
    """ Given a set of output numbers, it computes the average energy components of the outputs """
    energy_evolution = []
    r = compute_radial_coordinate(levelmax)
    dx = 1.5E+03/2.**levelmax
    r_conv_up = int(6.60915e2/dx)
    r_conv_down = int(4.86990e2/dx)
    mask = np.where((r>=r_conv_down) & (r<=r_conv_up))
    # Loop
    for n in n_outputs:
        output = RamsesOutput()
        output.read(folder_data, n, norms=norms)
        energy_output = total_energy(output) 
        mean_values = np.array([np.mean(energy_output[k][mask]) for k in energy_output.keys()])
        energy_evolution.append(mean_values)
    energy_evolution = np.array(energy_evolution)
    return energy_evolution

def plot_energy_evolution(energy_evolution, only_etot=False):
    """ Simple plotting routine to plot the evolution in time of the energy components """
    # Get energy components
    etot = energy_evolution[:,0]
    ei   = energy_evolution[:,1]
    ekin = energy_evolution[:,2]
    emag = energy_evolution[:,3]
    # Prepare plot
    fig, ax = plt.subplots(figsize=(5,5))
    # Plot lines
    if not only_etot:
        ax.plot(ei  , label=r'$e_{i}$')
        ax.plot(ekin, label=r'$e_{kin}$')
        ax.plot(emag, label=r'$e_{mag}$')
    ax.plot(etot, label=r'$e_{tot}$', linestyle=':')
    ax.legend()
    ax.set_yscale('log')
    #ax.set_ylim([max(np.log10(etot))-1, max(np.log10(etot))+1])
    return fig, ax

# %% [markdown]
# #### Compute energies for a sequence of outputs and plot the evolution

# %%
n_outputs = np.arange(1, 101, 10)
energy_evolution = compute_conv_zone_energy_evolution(n_outputs, 7)
# Out:
# Processing 576 files in /home/jcaniv/scratch/eiger/dynamo/output_00001
#  10% : read     211176 cells,          0 particles
#  20% : read     422344 cells,          0 particles
#  30% : read     629872 cells,          0 particles
#  40% : read     841040 cells,          0 particles
#  50% : read    1048576 cells,          0 particles
#  60% : read    1259744 cells,          0 particles
#  70% : read    1470920 cells,          0 particles
#  80% : read    1678456 cells,          0 particles
#  90% : read    1889624 cells,          0 particles
# Loaded: 2097152 cells, 0 particles.
# Processing 576 files in /home/jcaniv/scratch/eiger/dynamo/output_00011
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [31], line 2
#       1 n_outputs = np.arange(1, 101, 10)
# ----> 2 energy_evolution = compute_conv_zone_energy_evolution(n_outputs, 7)
#
# Cell In [30], line 51, in compute_conv_zone_energy_evolution(n_outputs, levelmax)
#      49 for n in n_outputs:
#      50     output = RamsesOutput()
# ---> 51     output.read(folder_data, n, norms=norms)
#      52     energy_output = total_energy(output)
#      53     mean_values = np.array([np.mean(energy_output[k][mask]) for k in energy_output.keys()])
#
# File ~/projects/ramses_convection/modelS/ramses_global_models.py:188, in RamsesOutput.read(self, folder, n, vars, save, norms)
#     186     vars = list(self._variables.keys())
#     187 # Read output
# --> 188 output, meta = readRamsesOutput(folder, n, vars)
#     189 # Save variables
#     190 for var_name in self._variables.keys():
#
# File ~/projects/ramses_convection/modelS/ramses_global_models.py:297, in readRamsesOutput(folder, n, var_list)
#     292 """
#     293 A routine that uses the Osyris module to read a Ramses binary
#     294 output and put it in a Ramses class
#     295 """
#     296 # Read data with osyris
# --> 297 data = osyris.Dataset(n, path=folder).load()
#     298 hydro = data['hydro']
#     299 amr = data['amr']
#
# File /data/jcaniv/conda/envs/myenv/lib/python3.10/site-packages/osyris/core/dataset.py:88, in Dataset.load(self, *args, **kwargs)
#      87 def load(self, *args, **kwargs):
# ---> 88     groups = self.loader.load(*args, meta=self.meta, units=self.units, **kwargs)
#      89     for name, group in groups.items():
#      90         self[name] = group
#
# File /data/jcaniv/conda/envs/myenv/lib/python3.10/site-packages/osyris/io/loader.py:148, in Loader.load(self, select, cpu_list, sortby, meta, units)
#     143     fname = utils.generate_fname(meta["nout"],
#     144                                  meta["path"],
#     145                                  ftype=group,
#     146                                  cpuid=cpu_num)
#     147     with open(fname, mode='rb') as f:
# --> 148         reader.bytes = f.read()
#     150 # Read file headers
#     151 for reader in readers.values():
#
# KeyboardInterrupt:

# %%
plot_energy_evolution(energy_evolution, False)

# %%
plt.imshow(output.v.y)
plt.colorbar()
plt.imshow(output.v.x)

# %%
vmax = 40000
L = 0.1*vmax**3
L*1e-11
# Out:
# 63.99999999999999

# %%
Y, X = np.mgrid[0:2**10, 0:2**10]
v = output.v.norm
strm = plt.streamplot(X[400:600,0:200],Y[400:600,0:200],output.v.x[400:600,0:200],output.v.y[400:600,0:200], color=np.log10(np.sqrt(output.v.x**2 + output.v.y**2))[400:600,0:200], density=1, cmap='jet')
fig.colorbar(strm.lines)

# %%
F = 1.28*1e11
(F/0.1*4*np.pi)**(1./3.)
# Out:
# 25242.94055441456

# %%
const.R_sun.to(u.Mm)
# Out:
# <Quantity 695.7 Mm>

# %%
output.dx*(2**output.levelmax)
# Out:
# 1500.0

# %%
# Params
l = 7
ngrid = 2**7
boxlen = 1.39140E+03
boundaries = [4.86990E+02, 6.60915E+02]
heating_dr = 40.

# Compute radial coordinate
x,y,z = np.meshgrid(np.arange(ngrid), np.arange(ngrid), np.arange(ngrid))
x = x-(ngrid-1)/2
y = y-(ngrid-1)/2
z = z-(ngrid-1)/2
r = np.sqrt(x**2 + y**2 + z**2)

# find radial index of boundaries
dx = boxlen/ngrid
cool_ri = (boundaries[1]-heating_dr)/dx
cool_rf = (boundaries[1])/dx
heat_ri = (boundaries[0])/dx
heat_rf = (boundaries[0]+heating_dr)/dx

# Coordinates in the heating volume:
heat_mask = np.where((r>heat_ri) & (r<heat_rf))
cool_mask = np.where((r>cool_ri) & (r<cool_rf))

# %%
# Values from code   
n_heat_ramses = 100120.00000000000
n_cool_ramse  = 160624.00000000000
   
vol_heat_ramses = 6.2375399999999991E-009   
vol_cool_ramses = -3.8879775425839222E-009

# %%
# Theoretical values

# %%
vol_energy =  3.0e-8*2.07918E-01
print('n_heat_th = ',heat_mask[0].shape)
print('n_cool_th = ',cool_mask[0].shape)
print('vol_heat_th = ',vol_energy)
print('vol_cool_th = ',-vol_energy*heat_mask[0].shape[0]/cool_mask[0].shape[0])
# Out:
# n_heat_th =  (100120,)
# n_cool_th =  (160624,)
# vol_heat_th =  6.237539999999999e-09
# vol_cool_th =  -3.887977542583922e-09
